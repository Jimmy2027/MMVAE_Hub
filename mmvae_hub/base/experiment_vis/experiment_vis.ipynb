# %%
from mmvae_hub.base.experiment_vis.utils import *
from mmvae_hub.base.utils.flags_utils import json2dict
import glob
from pathlib import Path

from matplotlib import pyplot as plt
from tensorflow.compat.v1.train import summary_iteratorimport

glob
# Out:
# [16:34:26 CEST] Log file: /Users/Hendrik/Documents/master_4/MMVAE_Hub/mmvae_hub/logger/logs/UTC-20210420-143426.log
# [16:34:37 CEST] Enabling eager execution
# [16:34:37 CEST] Enabling v2 tensorshape
# [16:34:37 CEST] Enabling resource variables
# [16:34:37 CEST] Enabling tensor equality
# [16:34:37 CEST] Enabling control flow v2

# %%
config_path = glob.glob('*.json')[0]
config = json2dict(config_path)
experiment_dir = Path(config['experiment_dir'])

tensorboard_logs_dir = experiment_dir / 'logs'
logs_dict = get_logs_dict(tensorboard_logs_dir)
# Out:
# [16:34:37 CEST] From /Users/Hendrik/opt/anaconda3/envs/mmvae/lib/python3.9/site-packages/tensorflow/python/summary/summary_iterator.py:31: tf_record_iterator (from tensorflow.python.lib.io.tf_record) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use eager execution and:
# `tf.data.TFRecordDataset(path)`

# %% [markdown]
# # Latent Representation

# %%
plot_lr_accuracy(tensorboard_logs_dir)

# %% [markdown]
# # Generation

# %%
# plot_gen_results(tensorboard_logs_dir)
plot_logs('Generation', logs_dict, together=True)

# %% [markdown]
# # Train logs

# %%
plot_logs('train', logs_dict)

# %% [markdown]
# # Test logs

# %%
plot_logs('test', logs_dict)

# %% [markdown]
# # Likelihoods

# %%
plot_logs('Likelihood', logs_dict, True)
